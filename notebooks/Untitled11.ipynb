# %%
# !pip install astropy
# Out:
# ...
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f0f24876d60>: Failed to establish a new connection: [Errno 101] Network is unreachable')': /packages/aa/04/1ebf4192978ca29ac84d71fa8bf70a6b86daf88a61b7e6d957659ed4367a/astropy-5.3.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f0f24876f40>: Failed to establish a new connection: [Errno 101] Network is unreachable')': /packages/aa/04/1ebf4192978ca29ac84d71fa8bf70a6b86daf88a61b7e6d957659ed4367a/astropy-5.3.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ...

# %%
import fitsio

# %%
import numpy as np

# %%
import pandas as pd

# %%
import glob

# %%
fnames = glob.glob('/project/chihway/data/decade/coaddcat_pz/*')

# %%
for fname in fnames:
    df = pd.DataFrame(fitsio.read(fname))

    print(np.isnan(df).any())
# Out:
# index              False
# COADD_OBJECT_ID    False
# RA                 False
# DEC                False
# FLUX_AUTO_G        False
# FLUX_AUTO_R        False
# FLUX_AUTO_I        False
# FLUX_AUTO_Z        False
# FLUXERR_AUTO_G     False
# FLUXERR_AUTO_R     False
# FLUXERR_AUTO_I     False
# FLUXERR_AUTO_Z     False
# BDF_FLUX_G         False
# BDF_FLUX_R         False
# BDF_FLUX_I         False
# BDF_FLUX_Z         False
# BDF_FLUX_ERR_G     False
# BDF_FLUX_ERR_R     False
# BDF_FLUX_ERR_I     False
# BDF_FLUX_ERR_Z     False
# dtype: bool
# index              False
# COADD_OBJECT_ID    False
# RA                 False
# DEC                False
# FLUX_AUTO_G        False
# FLUX_AUTO_R        False
# FLUX_AUTO_I        False
# FLUX_AUTO_Z        False
# FLUXERR_AUTO_G     False
# FLUXERR_AUTO_R     False
# FLUXERR_AUTO_I     False
# FLUXERR_AUTO_Z     False
# BDF_FLUX_G         False
# BDF_FLUX_R         False
# BDF_FLUX_I         False
# BDF_FLUX_Z         False
# ...

# %%
df
# Out:
#        index  COADD_OBJECT_ID          RA       DEC  FLUX_AUTO_G  FLUX_AUTO_R  \
# 0          0       7114490010  153.532210 -7.497684   458.390594  1059.391846
# 1          1       7114489984  153.302520 -7.486158   181.091492   188.878113
# 2          2       7114490031  153.185895 -7.492038    87.915359   170.674576
# 3          3       7114490036  153.605449 -7.479894  1662.622925  6575.768555
# 4          4       7114490089  153.439671 -7.486308   114.156822   163.546265
# ...      ...              ...         ...       ...          ...          ...
# 48513  48513       7114540409  153.358391 -8.192844   190.670502   731.784729
# 48514  48514       7114540390  153.452755 -8.192619    41.064762   199.367035
# 48515  48515       7114540428  153.426915 -8.193038    26.545250   159.575928
# 48516  48516       7114540205  153.326125 -8.189683   107.235222   212.488342
# 48517  48517       7114540375  153.390463 -8.192387   290.367859    93.487259
#
# ...

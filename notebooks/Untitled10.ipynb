# %%
import h5py
import numpy
import matplotlib.pyplot as plt

# %%
with h5py.File('/project/chihway/data/decade/coaddcat_pz/pz_sva1_weights_DELVE_gold_DES0753-0416.h5') as f:
    for key in f.keys():
        print(key, numpy.array(f[key]))
    plt.hist(numpy.array(f['Z_B']), bins=23)
# Out:
# CHI_SQ [1.0831678  0.8162386  0.30749625 ... 0.6564091  0.01383525 0.07554568]
# ID [6933774554 6933774577 6933774599 ... 6933834091 6933834111 6933834131]
# M_0 [14.436905 23.7306   23.555483 ... 22.263538 21.117304 23.47449 ]
# ODDS [0.6991709  0.330076   0.19103397 ... 0.94680154 0.99496144 0.32897246]
# T_B [4. 2. 5. ... 1. 1. 2.]
# T_ML [3. 1. 5. ... 1. 1. 1.]
# Z_B [0.245 0.645 0.805 ... 0.785 0.565 0.575]
# Z_B_MAX [0.30690452 0.855      1.265      ... 0.8737547  0.6428157  0.855     ]
# Z_B_MIN [0.085     0.415     0.425     ... 0.6962453 0.4871843 0.445    ]
# Z_MEAN [0.20060201 0.6429683  0.8600619  ... 0.7850528  0.56867427 0.65242493]
# Z_ML [2.215 0.375 0.855 ... 0.795 0.565 0.455]
# Z_SAMP [0.115 0.315 1.035 ... 0.845 0.595 0.585]
# Z_SIG [0.07409642 0.22340705 0.42665738 ... 0.04580061 0.02942997 0.20188737]

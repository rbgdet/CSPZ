# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/home/raulteixeira/scratch-midway2/CosmicShearData/DELVE_data_with_zspec012623.csv.gz')

# %%
data.to_hdf('/home/raulteixeira/scratch-midway2/CosmicShearData/DELVE_data_with_zspec012623.h5', key='df')

# %%
for column in data.columns:
    if column[0:4]=='FLUX':
        data[column]*=1e-12

# %%
data
# Out:
#           index  COADD_OBJECT_ID          RA        DEC   FLUX_AUTO_G  \
# 0           213       7243731529  119.774639  15.833082  8.483194e-08
# 1           278       7243734941  119.807899  15.805026  1.520439e-09
# 2          1315       7047807542  140.421416   0.691939  1.717676e-09
# 3          1319       7047807700  140.733352   0.690826  4.455959e-09
# 4          1338       7047808627  140.509716   0.676549  8.477071e-09
# ...         ...              ...         ...        ...           ...
# 524021  3418575       7187028075  168.845312  25.176688  1.510024e-09
# 524022  3419242       7187045286  168.396980  24.900979  2.026266e-09
# 524023  3419261       7187046266  168.309613  24.883887  1.833459e-09
# 524024  3419612       7187449446  168.491137  26.053923  1.351934e-09
# 524025  3419681       7187452622  168.310998  25.995593  5.420074e-08
#
#          FLUX_AUTO_R   FLUX_AUTO_I   FLUX_AUTO_Z  FLUXERR_AUTO_G  \
# ...

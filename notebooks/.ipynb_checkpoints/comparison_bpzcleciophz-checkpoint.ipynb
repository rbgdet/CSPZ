# %%
# 3rd party # remove imports that are not needed
import numpy as np
import pandas as pd
import pylab as plt
import h5py
import matplotlib
# %matplotlib inline
from astropy.utils.data import download_file  #import file from URL
from matplotlib.ticker import NullFormatter
import astropy.table
#'/data/des90.a/data/raulteix/software/DESC_BPZ/tests/DELVEdata_example_output_6416.bpz.h5'

# %%
dataclecio = astropy.table.Table.read('/data/des90.a/data/jsanch87/DELVE_w_photozs_06416.fits')

# %%
databpz = h5py.File('/data/des90.a/data/raulteix/software/DESC_BPZ/tests/DELVEdata_example_output_6416.bpz.h5', 'r')

# %%
data_clecio, data_bpz = dataclecio['z'], dataclecio['Z_ML']

# %%
plt.hist(data_bpz-data_clecio, range=(0.01, 1.2))
plt.show()
plt.scatter(data_bpz, data_bpz-data_clecio)
plt.show()

# %%
n, bins, patches = plt.hist(data_bpz, range = (0.01, 1.2), bins = 22)

# %%
nc, binsc, patchesc = plt.hist(data_clecio, range = (0.01, 1.2), bins = 22)

# %%
bins[1:23].size
# Out:
# 22

# %%
plt.scatter(bins[1:23], n-nc)

# %%
plt.xlim(-1.2, 1.2)
plt.scatter(data_bpz, data_bpz-data_clecio)

# %%
plt.hist(data_bpz[data_bpz>0.01]-data_clecio, range=(-1.2, 1.2), bins=30)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-d0a2b42e46ea> in <module>
# ----> 1 plt.hist(data_bpz[data_bpz>0.01]-data_clecio, range=(-1.2, 1.2), bins=30)
#       2 plt.show()
#
# ValueError: operands could not be broadcast together with shapes (2965,) (5946,)

# %%
plt.hist2d(data_bpz, data_clecio, range=[(0, 1.2),(-1.2, 1.2)], bins=30)
plt.axhline(0.0, ls='--', c='r')
plt.show()

# %%
plt.hist2d(data_bpz, data_clecio, range=[(0, 1.2),(0, 1.2)], bins=30)
plt.plot(np.linspace(0, 1.2), np.linspace(0, 1.2), 'r--')
plt.show()

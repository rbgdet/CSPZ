# %%
import subprocess as sp
import time

start_time = time.time()
for i in range(1,50):
    print(i)
    column_path =  '/home/raulteixeira/repos/DESC_BPZ/tests/CosmicShearPZ_BDF_Flux.columns'
    output_path =  f'/project2/chihway/raulteixeira/data/BPZ_bdf/hdfn_gen/CWWSB4/BPZ_BDF_HDFN_CWWSB4_{i:02}.h5'
    #h5dir = f'/project2/chihway/raulteixeira/data/bdf_photometry/dr3_1_1_bdf_metacal_cut_BPZ_input_{i:02}.h5'

    list_lines = ['COLUMNS         %s'%column_path,
                 f'OUTPUT          %s'%output_path,
                  'SPECTRA         CWWSB4.list', #eg CWWSB4.list 
                  'PRIOR           hdfn_gen', #eg hdfn_gen
                  'DZ              0.01', 
                  'ZMIN            0.005',
                  'ZMAX            3.505', 
                  'MAG             no',
                  'NEW_AB          no', 
                  'MADAU           no #TURN OFF MADAU!!!!',
                  'EXCLUDE         none', 
                  'CHECK           yes', 
                  '#ZC             1.0,2.0', 
                  '#FC             0.2,0.4',
                  'VERBOSE         no', 
                  '#INTERP         0', 
                  'ODDS            0.68',
                 f'PROBS           no',
                 f'PROBS2          no',
                 f'PROBS_LITE      no', 
                  'GET_Z           yes', 
                  'INTERACTIVE     yes', 
                  'PLOTS           no',
                  'SAMPLING        yes',
                  'NSAMPLES        1',
                  '#ONLY_TYPE      yes']

    #I removed all the "\n" from each line purely for visual considerations.
    #Now adding them back in with a single list comprehension line.
    list_lines = [l + '\n' for l in list_lines]
    #list_lines = (" \n ").join(list_lines)
    #Can't modify the example.pars directly.
    #If we run in parallel then multiple instances of script
    #will be rewriting same file at once and that won't work. 
    #So make temporary copy first.

    sp.run('echo "Hello"', shell = True)

    sp.run(f'cp /home/raulteixeira/repos/DESC_BPZ/tests/DELVEdata_Flux.pars /home/raulteixeira/repos/DESC_BPZ/tests/TEMP_bdf_hdfn_cwwsb4_6_will_{i:02}.pars', shell = True)

    pars = open(f'/home/raulteixeira/repos/DESC_BPZ/tests/TEMP_bdf_hdfn_cwwsb4_6_will_{i:02}.pars', mode='w')
    pars.writelines(list_lines)
    pars.close()
    print(time.time()-start_time)
# Out:
# 1
# Hello
# 0.031271934509277344
# 2
# Hello
# 0.059053659439086914
# 3
# Hello
# 0.08498668670654297
# 4
# Hello
# 0.11489224433898926
# 5
# Hello
# 0.14371824264526367
# 6
# Hello
# 0.17076396942138672
# 7
# Hello
# 0.19736862182617188
# 8
# Hello
# 0.22667980194091797
# 9
# Hello
# 0.25777435302734375
# 10
# Hello
# 0.2840251922607422
# 11
# Hello
# 0.30937623977661133
# 12
# Hello
# 0.3334228992462158
# 13
# Hello
# 0.3570542335510254
# 14
# Hello
# 0.38330745697021484
# 15
# Hello
# 0.40933752059936523
# 16
# Hello
# 0.43691039085388184
# 17
# Hello
# 0.4613182544708252
# 18
# Hello
# 0.48485636711120605
# 19
# Hello
# 0.5064592361450195
# 20
# Hello
# 0.535663366317749
# 21
# Hello
# 0.5623047351837158
# 22
# Hello
# 0.5872669219970703
# 23
# Hello
# 0.617814302444458
# 24
# Hello
# 0.6474692821502686
# 25
# Hello
# 0.6760420799255371
# 26
# Hello
# 0.7034542560577393
# 27
# Hello
# 0.7275435924530029
# 28
# Hello
# 0.7528765201568604
# 29
# Hello
# 0.7802550792694092
# 30
# Hello
# 0.8098769187927246
# 31
# Hello
# 0.8389356136322021
# 32
# Hello
# 0.8652477264404297
# 33
# Hello
# 0.8912353515625
# 34
# Hello
# 0.9212441444396973
# 35
# Hello
# 0.9481985569000244
# 36
# Hello
# 0.975898265838623
# 37
# Hello
# 1.0044057369232178
# 38
# Hello
# 1.0314950942993164
# 39
# Hello
# 1.056363821029663
# 40
# Hello
# 1.0880436897277832
# 41
# Hello
# 1.1165878772735596
# 42
# Hello
# 1.141599178314209
# 43
# Hello
# 1.1668469905853271
# 44
# Hello
# 1.198840856552124
# 45
# Hello
# 1.226783037185669
# 46
# Hello
# 1.2547767162322998
# 47
# Hello
# 1.2851438522338867
# 48
# Hello
# 1.3129534721374512
# 49
# Hello
# 1.342278242111206

# %%
i=1
column_path =  '/home/raulteixeira/repos/DESC_BPZ/tests/CosmicShearPZ_BDF_Flux.columns'
output_path =  f'/project2/chihway/raulteixeira/data/BPZ_bdf/hdfn_gen/CWWSB4_6_will/BPZ_BDF_HDFN_CWWSB4_6_WILL_{i:02}_2e5.h5'
#h5dir = f'/project2/chihway/raulteixeira/data/bdf_photometry/dr3_1_1_bdf_metacal_cut_BPZ_input_{i:02}.h5'

list_lines = ['COLUMNS         %s'%column_path,
             f'OUTPUT          %s'%output_path,
              'SPECTRA         CWWSB4_6_will.list', #eg CWWSB4.list 
              'PRIOR           hdfn_gen', #eg hdfn_gen
              'DZ              0.01', 
              'ZMIN            0.005',
              'ZMAX            3.505', 
              'MAG             no',
              'NEW_AB          no', 
              'MADAU           no #TURN OFF MADAU!!!!',
              'EXCLUDE         none', 
              'CHECK           yes', 
              '#ZC             1.0,2.0', 
              '#FC             0.2,0.4',
              'VERBOSE         no', 
              '#INTERP         0', 
              'ODDS            0.68',
             f'PROBS           no',
             f'PROBS2          no',
             f'PROBS_LITE      no', 
              'GET_Z           yes', 
              'INTERACTIVE     yes', 
              'PLOTS           no',
              'SAMPLING        yes',
              'NSAMPLES        1',
              '#ONLY_TYPE      yes']

#I removed all the "\n" from each line purely for visual considerations.
#Now adding them back in with a single list comprehension line.
list_lines = [l + '\n' for l in list_lines]
#list_lines = (" \n ").join(list_lines)
#Can't modify the example.pars directly.
#If we run in parallel then multiple instances of script
#will be rewriting same file at once and that won't work. 
#So make temporary copy first.

sp.run('echo "Hello"', shell = True)

sp.run(f'cp /home/raulteixeira/repos/DESC_BPZ/tests/DELVEdata_Flux.pars /home/raulteixeira/repos/DESC_BPZ/tests/TEMP_bdf_hdfn_cwwsb4_6_will_{i:02}_1e5.pars', shell = True)

pars = open(f'/home/raulteixeira/repos/DESC_BPZ/tests/TEMP_bdf_hdfn_cwwsb4_6_will_{i:02}_2e5.pars', mode='w')
pars.writelines(list_lines)
pars.close()
# Out:
# Hello

# %%
import subprocess as sp
import time
import h5py
import pandas as pd

N=int(2e5)
start_time = time.time()
for i in range(1,50):
    h5dir = f'/project2/chihway/raulteixeira/data/bdf_photometry/dr3_1_1_bdf_metacal_cut_BPZ_input_{i:02}.h5' 
    #h5dir = f'/project2/chihway/raulteixeira/data/bdf_photometry/dr3_1_1_bdf_metacal_cut_BPZ_input_{i:02}.h5'
#     df = pd.read_hdf(h5dir)
#     df = df[:N]
#     print(df)
#     h5dir = f'/project2/chihway/raulteixeira/data/bdf_photometry/dr3_1_1_bdf_metacal_cut_BPZ_input_.h5'
#    df.to_hdf(h5dir, key='df')
    
    lines = ['#!/bin/sh', '#SBATCH -t 20:00:00',
             '#SBATCH --partition=broadwl',
             '#SBATCH --account=pi-chihway',
             f'#SBATCH --job-name=BPZ{i:02}',
             '#SBATCH --nodes=1',
             '#SBATCH --ntasks-per-node=28', 
             f'python -u /home/raulteixeira/repos/DESC_BPZ/scripts/bpz.py '\
           + h5dir + f' -P /home/raulteixeira/repos/DESC_BPZ/tests/TEMP_bdf_hdfn_cwwsb4_{i:02}.pars',
             'echo "end"']

    lines = [l + '\n' for l in lines]

    bash_job_path = f'/home/raulteixeira/jobs/bpz_bdf_will_hdfn/bpz_BDF_HDFN_{i:02}.sh'
    pars = open(bash_job_path, mode='w')
    pars.writelines(lines)
    pars.close()

    sp.run(f'sbatch {bash_job_path}', shell = True)

    print(time.time()-start_time)
# Out:
# Submitted batch job 27558395
# 0.206193208694458
# Submitted batch job 27558396
# 0.3048436641693115
# Submitted batch job 27558397
# 0.38283634185791016
# Submitted batch job 27558398
# 0.47218918800354004
# Submitted batch job 27558399
# 0.5480728149414062
# Submitted batch job 27558400
# 0.6368465423583984
# Submitted batch job 27558401
# 0.7140214443206787
# Submitted batch job 27558402
# 0.7969927787780762
# Submitted batch job 27558403
# 0.8901596069335938
# Submitted batch job 27558404
# 0.9698529243469238
# Submitted batch job 27558405
# 1.0413029193878174
# Submitted batch job 27558406
# 1.1180989742279053
# Submitted batch job 27558407
# 1.1988821029663086
# Submitted batch job 27558408
# 1.2687978744506836
# Submitted batch job 27558409
# 1.362107515335083
# Submitted batch job 27558410
# 1.4326882362365723
# Submitted batch job 27558411
# 1.5076441764831543
# Submitted batch job 27558412
# 1.5761983394622803
# Submitted batch job 27558413
# 1.6694738864898682
# Submitted batch job 27558414
# 1.7344355583190918
# Submitted batch job 27558415
# 1.8177258968353271
# Submitted batch job 27558416
# 1.8943588733673096
# Submitted batch job 27558417
# 1.9626779556274414
# Submitted batch job 27558418
# 2.01888370513916
# Submitted batch job 27558419
# 2.095768451690674
# Submitted batch job 27558420
# 2.1711137294769287
# Submitted batch job 27558421
# 2.2648372650146484
# Submitted batch job 27558422
# 2.341736078262329
# Submitted batch job 27558423
# 2.439410924911499
# Submitted batch job 27558424
# 2.5337700843811035
# Submitted batch job 27558425
# 2.6019248962402344
# Submitted batch job 27558426
# 2.6731183528900146
# Submitted batch job 27558427
# 2.758673667907715
# Submitted batch job 27558428
# 2.849600076675415
# Submitted batch job 27558429
# 2.9728870391845703
# Submitted batch job 27558430
# 3.0296273231506348
# Submitted batch job 27558431
# 3.0890069007873535
# Submitted batch job 27558432
# 3.1587369441986084
# Submitted batch job 27558433
# 3.2222070693969727
# Submitted batch job 27558434
# 3.2834126949310303
# Submitted batch job 27558435
# 3.3594160079956055
# Submitted batch job 27558436
# 3.442293882369995
# Submitted batch job 27558437
# 3.525721788406372
# Submitted batch job 27558438
# 3.6032521724700928
# Submitted batch job 27558439
# 3.6760523319244385
# Submitted batch job 27558440
# 3.7547271251678467
# Submitted batch job 27558441
# 3.827146291732788
# Submitted batch job 27558442
# 3.9082577228546143
# Submitted batch job 27558443
# 3.987746238708496

# %%
print(lines[-2])
# Out:
# python /home/raulteixeira/repos/DESC_BPZ/scripts/bpz.py /project2/chihway/raulteixeira/data/bdf_photometry/dr3_1_1_bdf_metacal_cut_BPZ_input_01_2e5.h5 -P /home/raulteixeira/repos/DESC_BPZ/tests/TEMP_bdf_hdfn_cwwsb4_6_will_01_2e5.pars

# %%
# !python /home/raulteixeira/repos/DESC_BPZ/scripts/bpz.py /project2/chihway/raulteixeira/data/bdf_photometry/dr3_1_1_bdf_metacal_cut_BPZ_input_01_2e5.h5 -P /home/raulteixeira/repos/DESC_BPZ/tests/TEMP_bdf_hdfn_cwwsb4_6_will_01_2e5.pars
# Out:
# Current time  Tue May 23 12:30:42 2023
#
# RAUL'S VERSION
# chunksize: 10000
#
# !!!!
# F_OBS:  [[  478.91807849   870.0108006   1813.98691787  2611.73487155]
#  [  118.312244    1888.8692327   4131.36873037  6558.44466247]
#  [ 1499.04049086  3260.76774885  6992.82680979 10270.12938488]
#  ...
#  [ 1240.40720229  3624.82494101  5982.29615304  8518.18737345]
#  [  455.76071188   763.10120074   646.48697699   851.12371929]
#  [  719.68074334  1756.88823051  2655.55816165  2953.02929038]] (200000, 4)
#
# !!!!!
#  EF_OBS [[212.56419068 174.5271462  262.43408677 439.03570429]
#  [181.56635499 137.846376   186.0143622  330.89197315]
#  [186.18530458 146.26863695 212.11914165 357.28884407]
#  ...
#  [ 23.72188469  46.1547728  118.18796031 135.60801052]
#  [ 22.29312758  46.64707618  77.77033647 101.51062194]
#  [ 23.7281307   43.90796963 111.77019041 128.44956233]] (200000, 4)
# pars.d['MAG']: no
# m0column name:  BDF_MAG_I
# BDF_MAG_I
# 21.8534146232846
# final length of trimmed dataset: 200000
# ng larger than chunksize, creating first chunk of size 10000
# 0.68 0.9944500000000001
# 0
# 0
# ML * prior -- NOT QUITE BAYESIAN
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 147000
# 148000
# 149000
# 150000
# 150000
# 151000
# 152000
# 153000
# 154000
# 155000
# 156000
# 157000
# ^C
# Traceback (most recent call last):
#   File "/home/raulteixeira/repos/DESC_BPZ/scripts/bpz.py", line 1492, in <module>

# %%
f'/project2/chihway/raulteixeira/data/bdf_photometry/dr3_1_1_bdf_metacal_cut_BPZ_input_01_1e5.h5'

# %%
    h5dir = f'/project2/chihway/raulteixeira/data/bdf_photometry/dr3_1_1_bdf_metacal_cut_BPZ_input_{i:02}.h5'
df = pd.read_hdf(h5dir)

# %%
df
# Out:
#          COADD_OBJECT_ID   BDF_FLUX_G   BDF_FLUX_R   BDF_FLUX_I    BDF_FLUX_Z  \
# 1128534       6895874367   478.918078   870.010801  1813.986918   2611.734872
# 1127482       6895874893   118.312244  1888.869233  4131.368730   6558.444662
# 1127489       6895876258  1499.040491  3260.767749  6992.826810  10270.129385
# 1127458       6895876787   428.334439  1514.273678  3687.603047   5689.248696
# 1127479       6895876891   518.992470  2931.906564  4629.004147   5942.901475
# ...                  ...          ...          ...          ...           ...
# 1102726       7255613031  1218.810775  1757.732226  2318.448466   2551.591028
# 1102739       7255613061   319.067750   423.481382   815.220587   1309.420283
# 1102729       7255613200   158.435017   358.763086   655.909422    933.479546
# 1102736       7255613697   121.807133   562.074459  1215.616233   1695.992252
# 1102724       7255613748   380.727435   919.917912  1776.453707   2038.206150
#
#          BDF_FLUX_ERR_G  BDF_FLUX_ERR_R  BDF_FLUX_ERR_I  BDF_FLUX_ERR_Z  \
# 1128534      212.564191      174.527146      262.434087      439.035704
# 1127482      181.566355      137.846376      186.014362      330.891973
# 1127489      186.185305      146.268637      212.119142      357.288844
# 1127458      206.715803      166.585941      257.871534      444.319000
# 1127479      195.922914      164.373478      217.091411      348.925010
# ...                 ...             ...             ...             ...
# 1102726       53.571917       88.285460       72.702788      168.330196
# 1102739       31.056123       54.242712       53.447101      126.526577
# 1102729       25.107873       47.029913       36.191368      101.411256
# 1102736       37.664747       72.310446       71.892884      169.304235
# 1102724       33.071993       62.704794       68.461419      138.626049
#
#          BDF_MAG_I
# 1128534  21.853415
# 1127482  20.959765
# 1127489  20.388368
# 1127458  21.083140
# 1127479  20.836281
# ...            ...
# 1102726  21.587006
# 1102739  22.721812
# 1102729  22.957890
# 1102736  22.288009
# 1102724  21.876115
#
# [1086842 rows x 10 columns]

# %%
# %%time
# !python /home/raulteixeira/repos/DESC_BPZ/scripts/bpz.py /project2/chihway/raulteixeira/data/bdf_photometry/dr3_1_1_bdf_metacal_cut_BPZ_input_01_1e5.h5 -P /home/raulteixeira/repos/DESC_BPZ/tests/TEMP_bdf_hdfn_cwwsb4_6_will_01.pars
# Out:
# Current time  Mon May 22 21:50:03 2023
#
# RAUL'S VERSION
# chunksize: 10000
#
# !!!!
# F_OBS:  [[  478.91807849   870.0108006   1813.98691787  2611.73487155]
#  [  118.312244    1888.8692327   4131.36873037  6558.44466247]
#  [ 1499.04049086  3260.76774885  6992.82680979 10270.12938488]
#  ...
#  [ 3487.89414958  6939.27939276  9366.28207951 10512.12943754]
#  [  787.54254802  1620.61138547  2136.61551708  2310.06137612]
#  [  677.36849316  1189.69942503  2410.47226057  3661.70426811]] (100000, 4)
#
# !!!!!
#  EF_OBS [[212.56419068 174.5271462  262.43408677 439.03570429]
#  [181.56635499 137.846376   186.0143622  330.89197315]
#  [186.18530458 146.26863695 212.11914165 357.28884407]
#  ...
#  [ 43.69662112  69.47139472  87.4077601  126.20537759]
#  [ 55.79309098  98.87507438 125.78764609 186.55489973]
#  [ 52.65627825  85.63684577 131.99572248 220.307881  ]] (100000, 4)
# m0column name:  BDF_MAG_I
# BDF_MAG_I
# 21.8534146232846
# final length of trimmed dataset: 100000
# File /project2/chihway/raulteixeira/data/BPZ_bdf/hdfn_gen/CWWSB4_6_will/BPZ_BDF_HDFN_CWWSB4_6_WILL_01 exists. Copying it to /project2/chihway/raulteixeira/data/BPZ_bdf/hdfn_gen/CWWSB4_6_will/BPZ_BDF_HDFN_CWWSB4_6_WILL_01.bak
# ng larger than chunksize, creating first chunk of size 10000
# 0.68 0.9944500000000001
# 0
# 0
# ML * prior -- NOT QUITE BAYESIAN
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# out_name /project2/chihway/raulteixeira/data/BPZ_bdf/hdfn_gen/CWWSB4_6_will/BPZ_BDF_HDFN_CWWSB4_6_WILL_01
#
#
# PHOTOMETRIC CALIBRATION TESTS
# /home/raulteixeira/repos/DESC_BPZ/scripts/bpz.py:1544: RuntimeWarning: invalid value encountered in true_divide
#   fratavg = sum(fw*frat, axis=0) / sum(fw, axis=0)
# If the dmag are large, add them to the .columns file (zp_offset), then re-run BPZ.
# (For better results, first re-run with -ONLY_TYPE yes to fit SEDs to known spec-z.)
#
#   fo/ft    dmag   nobj   filter
#     nan      nan     0   DECam_2014_g
#     nan      nan     0   DECam_2014_r
#     nan      nan     0   DECam_2014_i
#     nan      nan     0   DECam_2014_z
# fo/ft = Average f_obs/f_model weighted by f_obs/ef_obs for objects with ODDS >= 0.68
# dmag = magnitude offset which should be applied (added) to the photometry (zp_offset)
# nobj = # of galaxies considered in that filter (detected and high ODDS >= 0.68)
#
# Elapsed time 00:14:28
#
# CPU times: user 13.5 s, sys: 2.2 s, total: 15.7 s
# Wall time: 14min 36s

# %%
len(f['df/block0_values'])
# Out:
# 1086842

# %%
for i in range(27531076, 27531121):
    print(f'scancel {i}')
    #sp.run(f'scancel 275307{19+i}')
# Out:
# scancel 27531076
# scancel 27531077
# scancel 27531078
# scancel 27531079
# scancel 27531080
# scancel 27531081
# scancel 27531082
# scancel 27531083
# scancel 27531084
# scancel 27531085
# scancel 27531086
# scancel 27531087
# scancel 27531088
# scancel 27531089
# scancel 27531090
# scancel 27531091
# scancel 27531092
# scancel 27531093
# scancel 27531094
# scancel 27531095
# scancel 27531096
# scancel 27531097
# scancel 27531098
# scancel 27531099
# scancel 27531100
# scancel 27531101
# scancel 27531102
# scancel 27531103
# scancel 27531104
# scancel 27531105
# scancel 27531106
# scancel 27531107
# scancel 27531108
# scancel 27531109
# scancel 27531110
# scancel 27531111
# scancel 27531112
# scancel 27531113
# scancel 27531114
# scancel 27531115
# scancel 27531116
# scancel 27531117
# scancel 27531118
# scancel 27531119
# scancel 27531120
